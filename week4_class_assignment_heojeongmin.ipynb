# %%
import random
class MyDataLoader2:
    def __init__(self, data1, data2):
        # data1과 data2 크기는 같다고 가정합시다
        self.size = len(data1) 
        self.data1 = data1
        self.data2 = data2
 
    # __iter__에서는 나를 반환해주고 __next__에서는 for loop가
    # 돌떄마다 인쇄하고 싶은 값을 리턴합니다.
    def __iter__(self): 
        self.index = 0
        return self
 
    def __next__(self):
        if self.index >= self.size:
            raise StopIteration
            
        iterator = self.data1[self.index]+self.data2[self.index]
        self.index += 1
        return iterator
        ##################
        #data1과 data2를 더해서 리턴할 수 있는 iterator를 완성해주세요
        ##################
    def shuffle(self):
        random.shuffle(self.data1)
        random.shuffle(self.data2)
        #########
        # data1과 data2를 shuffle해주세요
        #########
    def make_square(self):
        result1 =list(map(lambda x: x**2, self.data1))
        result2 =list(map(lambda x: x**2, self.data2))
        self.data1 = result1
        self.data2 = result2
 
        ######### 
        # data1과 data2의 값들을 다 제곱해주세요!
        #########

# %%
# data1과 data2 크기는 같다고 가정합시다
loader = MyDataLoader2([i for i in range(300)], [i for i in range(300)])
loader.make_square() ## data1과 data2를 제곱할 수 있는 method를 완성해주세요!
loader.shuffle()
for i, x in enumerate(loader): # for loop 가 도니까 __iter__
    print("{} : {}".format(i,x)) # i번째 data1과 data2를 더한 값을 리턴하도록 만들어주세요!
# Out:
# 0 : 36040
# 1 : 31301
# 2 : 200
# 3 : 7229
# 4 : 97920
# 5 : 77480
# 6 : 24869
# 7 : 27976
# 8 : 21284
# 9 : 46121
# 10 : 94165
# 11 : 8737
# 12 : 4357
# 13 : 84274
# 14 : 53530
# 15 : 30224
# 16 : 6257
# 17 : 48745
# 18 : 24050
# 19 : 62413
# 20 : 28933
# 21 : 81
# 22 : 89480
# 23 : 109034
# 24 : 105209
# 25 : 64
# 26 : 38861
# 27 : 77813
# 28 : 128018
# 29 : 2941
# 30 : 43412
# 31 : 44057
# 32 : 67961
# 33 : 167074
# 34 : 83585
# 35 : 23620
# 36 : 51193
# 37 : 66905
# 38 : 78010
# 39 : 34816
# 40 : 16717
# 41 : 40265
# 42 : 81413
# 43 : 97826
# 44 : 39274
# 45 : 41413
# 46 : 63274
# 47 : 87200
# 48 : 92200
# 49 : 34481
# 50 : 56180
# 51 : 94792
# 52 : 64594
# 53 : 112500
# 54 : 13877
# 55 : 39185
# 56 : 46850
# 57 : 154377
# 58 : 109217
# 59 : 13185
# 60 : 26240
# 61 : 21124
# 62 : 123136
# 63 : 32113
# 64 : 129610
# 65 : 81925
# 66 : 45169
# 67 : 63925
# 68 : 119233
# 69 : 64970
# 70 : 80210
# 71 : 136882
# 72 : 9000
# 73 : 38898
# 74 : 64970
# 75 : 21506
# 76 : 24545
# 77 : 12393
# 78 : 124745
# 79 : 94865
# 80 : 56180
# 81 : 23866
# 82 : 85032
# 83 : 21557
# 84 : 11764
# 85 : 87073
# 86 : 44738
# 87 : 106873
# 88 : 51652
# 89 : 127553
# 90 : 2477
# 91 : 25492
# 92 : 63842
# 93 : 94266
# 94 : 6120
# 95 : 3169
# 96 : 28249
# 97 : 28297
# 98 : 56549
# 99 : 12541
# 100 : 30344
# 101 : 34996
# 102 : 12593
# 103 : 93865
# 104 : 9860
# 105 : 96730
# 106 : 18149
# 107 : 37732
# 108 : 68560
# 109 : 81253
# 110 : 62401
# 111 : 79300
# 112 : 18056
